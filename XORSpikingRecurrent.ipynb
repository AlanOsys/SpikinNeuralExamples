# %%
import spynnaker8 as sim
import pyNN.utility.plotting as plot
import matplotlib.pyplot as plt
n_neurons = 50
simtime = 5000
inp1 = [simtime/2,simtime/4*3]
inp2 = [simtime/4,simtime/4*3]
xor = [simtime/4,simtime/2]
sim.setup(timestep=0.1)
pre_pop = sim.Population(n_neurons,sim.IF_curr_exp(),label="Pre")
post_pop = sim.Population(n_neurons,sim.IF_curr_exp(),label="Post")
pre_noise = sim.Population(n_neurons,sim.SpikeSourceArray(spike_times=inp1),label="Noise_Pre")
pre_noise2 = sim.Population(n_neurons,sim.SpikeSourceArray(spike_times=inp2),label="Noise_Pre2")
post_noise = sim.Population(n_neurons,sim.SpikeSourceArray(spike_times=inp1),label="Noise_Post")
post_noise2 = sim.Population(n_neurons,sim.SpikeSourceArray(spike_times=inp2),label="Noise_Post2")
pre_pop.record(["spikes",'v'])
post_pop.record(["spikes",'v'])
# %matplotlib inline
# Out:
# 2022-05-07 19:06:13 INFO: Read cfg files: /home/bbpnrsoa/sPyNNaker/lib/python3.8/site-packages/spinn_front_end_common/interface/spinnaker.cfg, /home/bbpnrsoa/sPyNNaker/lib/python3.8/site-packages/spynnaker/pyNN/spynnaker.cfg, /home/bbpnrsoa/.spynnaker.cfg
# 2022-05-07 19:06:13 INFO: Will search these locations for binaries: /home/bbpnrsoa/sPyNNaker/lib/python3.8/site-packages/spinn_front_end_common/common_model_binaries : /home/bbpnrsoa/sPyNNaker/lib/python3.8/site-packages/spynnaker/pyNN/model_binaries
# 2022-05-07 19:06:13 WARNING: /home/bbpnrsoa/reports has 9 old reports that have not been closed
# 2022-05-07 19:06:13 WARNING: A timestep was entered that has forced sPyNNaker to automatically slow the simulation down from real time by a factor of 10. To remove this automatic behaviour, please enter a timescaleFactor value in your .spynnaker.cfg
# 2022-05-07 19:06:13 INFO: Setting time scale factor to 10.
# 2022-05-07 19:06:13 INFO: Setting machine time step to 100 micro-seconds.
# ['/home/bbpnrsoa/sPyNNaker/lib/python3.8/site-packages/spinn_front_end_common/interface/spinnaker.cfg', '/home/bbpnrsoa/sPyNNaker/lib/python3.8/site-packages/spynnaker/pyNN/spynnaker.cfg', '/home/bbpnrsoa/.spynnaker.cfg']

# %%
training = sim.Population(n_neurons, sim.SpikeSourceArray(spike_times=xor),label="Training")
sim.Projection(pre_noise,pre_pop,sim.OneToOneConnector(),
              synapse_type=sim.StaticSynapse(weight=2.0))
sim.Projection(post_noise,post_pop,sim.OneToOneConnector(),
              synapse_type=sim.StaticSynapse(weight=2.0))
sim.Projection(pre_noise2,pre_pop,sim.OneToOneConnector(),
              synapse_type=sim.StaticSynapse(weight=2.0))
sim.Projection(post_noise2,post_pop,sim.OneToOneConnector(),
              synapse_type=sim.StaticSynapse(weight=2.0))

sim.Projection(training,pre_pop,sim.OneToOneConnector(),
              synapse_type=sim.StaticSynapse(weight=5.0,delay=1.0))
sim.Projection(training,post_pop,sim.OneToOneConnector(),
              synapse_type=sim.StaticSynapse(weight=5.0,delay=5.0))

sim.Projection(post_pop,post_pop,sim.OneToOneConnector(),synapse_type=sim.StaticSynapse(weight=2.0))
sim.Projection(pre_pop,pre_pop,sim.OneToOneConnector(),synapse_type=sim.StaticSynapse(weight=2.0))
# Out:
# projection from pre Pre to post Pre with connector OneToOneConnector()

# %%
timing_rule = sim.SpikePairRule(tau_plus=20.0,tau_minus=20.0,A_plus=0.5,A_minus=0.5)
weight_rule = sim.AdditiveWeightDependence(w_max=5.0,w_min=0.0)
stdp_model = sim.STDPMechanism(timing_dependence=timing_rule,weight_dependence=weight_rule,
                              weight=0.0,delay=3.0)
stdp_projection = sim.Projection(pre_pop,post_pop,sim.OneToOneConnector(),synapse_type=stdp_model)

# %%
sim.run(simtime)
pre_neo = pre_pop.get_data(variables=["spikes"])
pre_spikes = pre_neo.segments[0].spiketrains
post_neo = post_pop.get_data(variables=["spikes"])
post_spikes = post_neo.segments[0].spiketrains
pre_v = pre_pop.get_data("v")
post_v = post_pop.get_data("v")
print(stdp_projection.getWeights())
sim.end()
# Out:
# 2022-05-07 19:06:19 INFO: Starting execution process
# 2022-05-07 19:06:19 INFO: Simulating for 50000 0.1ms timesteps using a hardware timestep of 1000us
# Adding Splitter selectors where appropriate
# there's_science_to_do!_When_I_look_out_there,_it_makes_me__
#  glad_I'm_not_you._I've_experiments_to_run._There_is________
# 2022-05-07 19:06:19 INFO: Time 0:00:00.010464 taken by SpynnakerSplitterSelector
# Adding delay extensions as required
# research_to_be_done._On_the_people_who_are_still_alive._And
#  believe_me_I_am_still_alive._I'm_doing_science_and_I'm_____
# 2022-05-07 19:06:19 INFO: Time 0:00:00.008982 taken by DelaySupportAdder
# 2022-05-07 19:06:22 INFO: Time 0:00:03.117560 taken by SpallocMaxMachineGenerator
# Preallocating resources for Extra Monitor support vertices
# still_alive._I_feel_fantastic_and_I'm_still_alive._While___
#  you're_dying_I'll_be_still_alive._And_when_you're_dead_I___
# 2022-05-07 19:06:31 INFO: Time 0:00:09.027786 taken by PreAllocateResourcesForExtraMonitorSupport
# Partitioning graph vertices
# will_be_still_alive......_Still_alive.....Still_alive!!!!!!
#  There_is_a_flower_within_my_heart,_Daisy,_Daisy!_Planted___
# Partitioning graph edges
# one_day_by_a_glancing_dart,_Planted_by_Daisy_Bell!_Whether_
#  she_loves_me_or_loves_me_not,_Sometimes_it's_hard_to_tell;_
# 2022-05-07 19:06:37 INFO: Time 0:00:05.317122 taken by SpYNNakerSplitterPartitioner
# Created spalloc job 6391306
# 2022-05-07 19:06:37 INFO: Created spalloc job 6391306
# Waiting for board power commands to complete.
# 2022-05-07 19:06:37 INFO: Waiting for board power commands to complete.
# 2022-05-07 19:06:42 INFO: Time 0:00:05.050045 taken by SpallocAllocator
# 2022-05-07 19:06:42 INFO: Creating transceiver for 10.11.218.97
# 2022-05-07 19:06:42 INFO: Working out if machine is booted
# 2022-05-07 19:06:46 INFO: Attempting to boot machine
# 2022-05-07 19:06:52 INFO: Found board with version [Version: SC&MP 3.4.1 at SpiNNaker:0:0:0 (built Thu Feb 11 15:36:44 2021)]
# 2022-05-07 19:06:52 INFO: Machine communication successful
# 2022-05-07 19:06:52 INFO: Detected a machine on IP address 10.11.218.97 which has 854 cores and 120.0 links
# 2022-05-07 19:06:52 INFO: Time 0:00:09.935316 taken by MachineGenerator
# Generating partitioner report
# Yet_I_am_longing_to_share_the_lot_Of_beautiful_Daisy_Bell!_
#  Daisy,_Daisy,_Give_me_your_answer,_do!_I'm_half_crazy,_All_
# 2022-05-07 19:06:52 INFO: Time 0:00:00.012484 taken by PartitionerReport
# 2022-05-07 19:06:52 INFO: Time 0:00:00.000435 taken by NetworkSpecificationReport
# Allocating virtual identifiers
# for_the_love_of_you!_It_won't_be_a_stylish_marriage,_I_____
#  can't_afford_a_carriage,_But_you'll_look_sweet_on_the_seat_
# 2022-05-07 19:06:52 INFO: Time 0:00:00.027983 taken by MallocBasedChipIDAllocator
# Inserting extra monitors into graphs
# Of_a_bicycle_built_for_two!_We_will_go_"tandem"_as_man_and_
#  wife,_Daisy,_Daisy!_"Ped'ling"_away_down_the_road_of_life,_
# 2022-05-07 19:06:52 INFO: Time 0:00:00.032144 taken by InsertExtraMonitorVerticesToGraphs
# Writing the board chip report
# I_and_my_Daisy_Bell!_When_the_road's_dark_we_can_both______
#  despise_P'liceman_and_"lamps"_as_well;_There_are_"bright___
# 2022-05-07 19:06:52 INFO: Time 0:00:00.008511 taken by BoardChipReport
# Getting number of keys required by each edge using application graph
# lights"_in_the_dazzling_eyes_Of_beautiful_Daisy_Bell!_I____
#  will_stand_by_you_in_"wheel"_or_woe,_Daisy,_Daisy!_You'll__
# 2022-05-07 19:06:52 INFO: Time 0:00:00.036495 taken by EdgeToNKeysMapper
# 2022-05-07 19:06:52 INFO: The time scale factor could be reduced to 4.987500000000001
# 2022-05-07 19:06:52 INFO: Time 0:00:00.001142 taken by LocalTDMABuilder
# Placing graph vertices via spreading over an entire machine
# be_the_bell(e)_which_I'll_ring_you_know!_Sweet_little_Daisy
#  Bell!_You'll_take_the_"lead"_in_each_"trip"_we_take,_Then__
# 2022-05-07 19:06:52 INFO: Time 0:00:00.029281 taken by SpreaderPlacer
# Inserting edges between vertices which require FR speed up functionality.
# if_I_don't_do_well;_I_will_permit_you_to_use_the_brake,_My_
#  beautiful_Daisy_Bell!_________2022-05-07 19:06:52 INFO: Time 0:00:00.030517 taken by InsertEdgesToExtraMonitorFunctionality
# Generating routing tables for data in system processes
# beautiful_Daisy_Bell!______________________________________
#  bacon_bacon_bacon_bacon_bacon_bacon_bacon_bacon_bacon_bacon
# 2022-05-07 19:06:52 INFO: Time 0:00:00.009185 taken by SystemMulticastRoutingGenerator
# Generating fixed router routes
# mushroom_mushroom_bacon_bacon_bacon_bacon_bacon_bacon_bacon
#  bacon_bacon_bacon_bacon_bacon_bacon_bacon_bacon_bacon_bacon
# 2022-05-07 19:06:52 INFO: Time 0:00:00.008500 taken by FixedRouteRouter
# Generating placement report
# mushroom_mushroom_bacon_bacon_bacon_bacon_bacon_bacon_bacon
#  snake_snake_bacon_bacon_bacon_bacon_bacon_bacon_bacon_bacon
# Generating placement by core report
# bacon_bacon_bacon_bacon_bacon_bacon_bacon_bacon_bacon_bacon
#  mushroom_mushroom_bacon_bacon_bacon_bacon_bacon_bacon_bacon
# 2022-05-07 19:06:52 INFO: Time 0:00:00.075324 taken by PlacerReportWithApplicationGraph
# Routing
# bacon_bacon_bacon_bacon_bacon_bacon_bacon_bacon_bacon_bacon
#  mushroom_mushroom_bacon_bacon_bacon_bacon_bacon_bacon_bacon
#
# 2022-05-07 19:06:52 INFO: Time 0:00:00.040415 taken by NerRouteTrafficAware
# Discovering tags
# bacon_bacon_bacon_bacon_bacon_bacon_bacon_bacon_bacon_bacon
#  mushroom_mushroom_bacon_bacon_bacon_bacon_bacon_bacon_bacon
# Allocating tags
# bacon_bacon_bacon_bacon_bacon_bacon_bacon_bacon_bacon_bacon
#  mushroom_mushroom_bacon_bacon_bacon_bacon_bacon_bacon_bacon
# 2022-05-07 19:06:52 INFO: Time 0:00:00.055151 taken by BasicTagAllocator
# Reporting Tags
# snake_snake_bacon_bacon_bacon_bacon_bacon_bacon_bacon_bacon
#  There_is_a_flower_within_my_heart,_Daisy,_Daisy!_Planted___
# 2022-05-07 19:06:52 INFO: Time 0:00:00.010770 taken by TagReport
# Getting constraints for machine graph
# one_day_by_a_glancing_dart,_Planted_by_Daisy_Bell!_Whether_
#  she_loves_me_or_loves_me_not,_Sometimes_it's_hard_to_tell;_
# 2022-05-07 19:06:52 INFO: Time 0:00:00.030140 taken by ProcessPartitionConstraints
# Calculating zones
# Yet_I_am_longing_to_share_the_lot_Of_beautiful_Daisy_Bell!_
#  Daisy,_Daisy,_Give_me_your_answer,_do!_I'm_half_crazy,_All_
# Allocating routing keys
# for_the_love_of_you!_It_won't_be_a_stylish_marriage,_I_____
#  can't_afford_a_carriage,_But_you'll_look_sweet_on_the_seat_
# 2022-05-07 19:06:52 INFO: Time 0:00:00.022357 taken by ZonedRoutingInfoAllocator
# Generating Routing info report
# Of_a_bicycle_built_for_two!_We_will_go_"tandem"_as_man_and_
#  wife,_Daisy,_Daisy!_"Ped'ling"_away_down_the_road_of_life,_
# 2022-05-07 19:06:52 INFO: Time 0:00:00.015252 taken by routingInfoReports
# Generating routing tables
# I_and_my_Daisy_Bell!_When_the_road's_dark_we_can_both______
#  despise_P'liceman_and_"lamps"_as_well;_There_are_"bright___
# 2022-05-07 19:06:52 INFO: Time 0:00:00.026590 taken by BasicRoutingTableGenerator
# 2022-05-07 19:06:52 INFO: Time 0:00:00.000841 taken by RouterCollisionPotentialReport
# Finding executable start types
# lights"_in_the_dazzling_eyes_Of_beautiful_Daisy_Bell!_I____
#  will_stand_by_you_in_"wheel"_or_woe,_Daisy,_Daisy!_You'll__
# 2022-05-07 19:06:52 INFO: Time 0:00:00.029706 taken by LocateExecutableStartType
# Initialising buffers
# be_the_bell(e)_which_I'll_ring_you_know!_Sweet_little_Daisy
#  Bell!_You'll_take_the_"lead"_in_each_"trip"_we_take,_Then__
# 2022-05-07 19:06:52 INFO: Time 0:00:00.040326 taken by BufferManagerCreator
# Allocating SDRAM for SDRAM outgoing egde partitions
# if_I_don't_do_well;_I_will_permit_you_to_use_the_brake,_My_
#  beautiful_Daisy_Bell!______________________________________
# 2022-05-07 19:06:52 INFO: Time 0:00:00.024352 taken by SDRAMOutgoingPartitionAllocator
# Generating data specifications
# On_the_farm,_ev'ry_Friday_On_the_farm,_it's_rabbit_pie_day_
#  So_ev'ry_Friday_that_ever_comes_along_I_get_up_early_and___
# 2022-05-07 19:06:53 INFO: Time 0:00:00.103524 taken by SpynnakerDataSpecificationWriter
# Preparing Routing Tables
# sing_this_little_song_Run_rabbit,_run_rabbit,_run,_run,_run
#  Run_rabbit,_run_rabbit,_run,_run,_run_Bang,_bang,_bang,____
# 2022-05-07 19:06:53 INFO: Time 0:00:00.010963 taken by RoutingSetup
# Finding binaries
# bang_goes_the_farmer's_gun_Run_rabbit,_run_rabbit,_run,_run
#  ,_run,_run_Run_rabbit,_run_rabbit,_run,_run,_run_Don't_give
# 2022-05-07 19:06:53 INFO: Time 0:00:00.028326 taken by GraphBinaryGatherer
# Running pair routing table compression on chip
# the_farmer_his_fun,_fun,_fun_He'll_get_by_without_his______
#  rabbit_pie_So_run_rabbit,_run_rabbit,_run,_run,_run_Run____
#
# 2022-05-07 19:06:56 INFO: Time 0:00:03.407379 taken by PairOnChipRouterCompression
# Generating Router table report
# run,_run,_run_Bang,_bang,_bang,_bang_goes_the_farmer's_gun_
#  Run_rabbit,_run_rabbit,_run,_run,_run,_run_Run_rabbit,_run_
# 2022-05-07 19:06:56 INFO: Time 0:00:00.009214 taken by unCompressedRoutingTableReports
# loading fixed routes
# rabbit,_run,_run,_run_Don't_give_the_farmer_his_fun,_fun,__
#  fun_He'll_get_by_without_his_rabbit_pie_So_run_rabbit,_run_
# 2022-05-07 19:06:56 INFO: Time 0:00:00.039966 taken by LoadFixedRoutes
# Executing data specifications and loading data for system vertices using Java
# rabbit,_run,_run,_run______________________________________
#  bacon_bacon_bacon_bacon_bacon_bacon_bacon_bacon_bacon_bacon
# 2022-05-07 19:06:57 INFO: Time 0:00:01.149095 taken by HostExecuteSystemDataSpecification
# Loading system executables onto the machine
# mushroom_mushroom_bacon_bacon_bacon_bacon_bacon_bacon_bacon
#  bacon_bacon_bacon_bacon_bacon_bacon_bacon_bacon_bacon_bacon
# 2022-05-07 19:07:03 INFO: Time 0:00:05.752191 taken by LoadSystemExecutableImages
# 2022-05-07 19:07:03 INFO: Time 0:00:00.001796 taken by TagsFromMachineReport
# Clearing tags
# mushroom_mushroom_bacon_bacon_bacon_bacon_bacon_bacon_bacon
#  snake_snake_bacon_bacon_bacon_bacon_bacon_bacon_bacon_bacon
# Loading Tags
# bacon_bacon_bacon_bacon_bacon_bacon_bacon_bacon_bacon_bacon
#  mushroom_mushroom_bacon_bacon_bacon_bacon_bacon_bacon_bacon
# 2022-05-07 19:07:03 INFO: Time 0:00:00.021147 taken by TagsLoader
# Executing data specifications and loading data for application vertices using Java
# bacon_bacon_bacon_bacon_bacon_bacon_bacon_bacon_bacon_bacon
#  mushroom_mushroom_bacon_bacon_bacon_bacon_bacon_bacon_bacon
# 2022-05-07 19:07:04 INFO: Time 0:00:01.128186 taken by HostExecuteApplicationDataSpecification
# Preparing to Expand Synapses
# snake_snake_bacon_bacon_bacon_bacon_bacon_bacon_bacon_bacon
#  bacon_bacon_bacon_bacon_bacon_bacon_bacon_bacon_bacon_bacon
# Expanding Synapses
# mushroom_mushroom_bacon_bacon_bacon_bacon_bacon_bacon_bacon
#  bacon_bacon_bacon_bacon_bacon_bacon_bacon_bacon_bacon_bacon
#
#
# 2022-05-07 19:07:11 INFO: Time 0:00:07.108696 taken by SynapseExpander
# Running bitfield generation on chip
# On_the_farm,_ev'ry_Friday_On_the_farm,_it's_rabbit_pie_day_
#  So_ev'ry_Friday_that_ever_comes_along_I_get_up_early_and___
#
#
# 2022-05-07 19:07:15 INFO: Time 0:00:03.351652 taken by OnChipBitFieldGenerator
# Finalising Retrieved Connections
# bang_goes_the_farmer's_gun_Run_rabbit,_run_rabbit,_run,_run
#  ,_run,_run_Run_rabbit,_run_rabbit,_run,_run,_run_Don't_give
# 2022-05-07 19:07:15 INFO: Time 0:00:00.026139 taken by FinishConnectionHolders
# Reading Routing Tables from Machine
# the_farmer_his_fun,_fun,_fun_He'll_get_by_without_his______
#  rabbit_pie_So_run_rabbit,_run_rabbit,_run,_run,_run_Run____
# 2022-05-07 19:07:15 INFO: Time 0:00:00.016458 taken by ReadRoutingTablesFromMachine
# Generating compressed router table report
# rabbit,_run_rabbit,_run,_run,_run_Run_rabbit,_run_rabbit,__
#  run,_run,_run_Bang,_bang,_bang,_bang_goes_the_farmer's_gun_
# 2022-05-07 19:07:15 INFO: Time 0:00:00.006647 taken by compressedRoutingTableReports
# Generating comparison of router table report
# Run_rabbit,_run_rabbit,_run,_run,_run,_run_Run_rabbit,_run_
#  rabbit,_run,_run,_run_Don't_give_the_farmer_his_fun,_fun,__
# 2022-05-07 19:07:15 INFO: Time 0:00:00.001810 taken by comparisonOfRoutingTablesReport
# Generating Routing summary report
# fun_He'll_get_by_without_his_rabbit_pie_So_run_rabbit,_run_
#  rabbit,_run,_run,_run______________________________________
# 2022-05-07 19:07:15 INFO: Time 0:00:00.015640 taken by CompressedRouterSummaryReport
# Reading Routing Tables from Machine
# There_is_a_flower_within_my_heart,_Daisy,_Daisy!_Planted___
#  one_day_by_a_glancing_dart,_Planted_by_Daisy_Bell!_Whether_
# 2022-05-07 19:07:15 INFO: Time 0:00:00.002175 taken by RoutingTableFromMachineReport
# Writing fixed route report
# she_loves_me_or_loves_me_not,_Sometimes_it's_hard_to_tell;_
#  Yet_I_am_longing_to_share_the_lot_Of_beautiful_Daisy_Bell!_
# 2022-05-07 19:07:15 INFO: Time 0:00:00.039392 taken by FixedRouteFromMachineReport
# Loading executables onto the machine
# Daisy,_Daisy,_Give_me_your_answer,_do!_I'm_half_crazy,_All_
#  for_the_love_of_you!_It_won't_be_a_stylish_marriage,_I_____
# 2022-05-07 19:07:28 INFO: Time 0:00:13.410928 taken by LoadApplicationExecutableImages
# 2022-05-07 19:07:28 INFO: Running for 1 steps for a total of 5000.0ms
# 2022-05-07 19:07:28 INFO: Run 1 of 1
# Generating SDRAM usage report
# can't_afford_a_carriage,_But_you'll_look_sweet_on_the_seat_
#  Of_a_bicycle_built_for_two!_We_will_go_"tandem"_as_man_and_
# 2022-05-07 19:07:28 INFO: Time 0:00:00.077452 taken by SdramUsageReportPerChip
# 2022-05-07 19:07:28 INFO: creating live event connection database in /home/bbpnrsoa/reports/2022-05-07-19-06-13-789421/run_1/input_output_database.db
# Creating graph description database
# wife,_Daisy,_Daisy!_"Ped'ling"_away_down_the_road_of_life,_
#  I_and_my_Daisy_Bell!_When_the_road's_dark_we_can_both______
# 2022-05-07 19:07:28 INFO: Time 0:00:00.064593 taken by DatabaseInterface
# 2022-05-07 19:07:28 INFO: ** Notifying external sources that the database is ready for reading **
# 2022-05-07 19:07:28 INFO: Time 0:00:00.001008 taken by CreateNotificationProtocol
# Getting provenance data from machine graph
# despise_P'liceman_and_"lamps"_as_well;_There_are_"bright___
#  lights"_in_the_dazzling_eyes_Of_beautiful_Daisy_Bell!_I____
# Getting provenance data from application graph
# will_stand_by_you_in_"wheel"_or_woe,_Daisy,_Daisy!_You'll__
#  be_the_bell(e)_which_I'll_ring_you_know!_Sweet_little_Daisy
# 2022-05-07 19:07:29 INFO: Time 0:00:00.095673 taken by GraphProvenanceGatherer
# Waiting for cores to be either in PAUSED or READY state
# Bell!_You'll_take_the_"lead"_in_each_"trip"_we_take,_Then__
#  if_I_don't_do_well;_I_will_permit_you_to_use_the_brake,_My_
# Updating run time
# beautiful_Daisy_Bell!______________________________________
#  This_was_a_triumph!_I'm_making_a_note_here_Huge_Success!!!_
# 2022-05-07 19:07:29 INFO: Time 0:00:00.035784 taken by ChipRuntimeUpdater
# 2022-05-07 19:07:29 INFO: *** Running simulation... ***
# Loading buffers
# It's_hard_to_overstate_my_satisfaction._Aperture_Science___
#  We_do_what_we_must_because_we_can_For_the_good_of_all_of_us
# 2022-05-07 19:07:29 INFO: ** Awaiting for a response from an external source to state its ready for the simulation to start **
# 2022-05-07 19:07:29 INFO: ** Sending start / resume message to external sources to state the simulation has started or resumed. **
# 2022-05-07 19:07:29 INFO: ** Awaiting for a response from an external source to state its ready for the simulation to start **
# 2022-05-07 19:07:29 INFO: Application started; waiting 50.1s for it to stop

# %%
line_properties = [{'color': 'r','markersize':4},{'color': 'b','markersize':2}]
plt.figure()
plot.Figure(
    # plot spikes
    plot.Panel(pre_spikes, post_spikes, yticks=True, xlim=(0, simtime),line_properties = line_properties),
    plot.Panel(pre_v.segments[0].filter(name='v')[0],yticks=True,xticks=True,legend=None,xlabel="Time"),
    plot.Panel(post_v.segments[0].filter(name='v')[0],yticks=True,xticks=True,legend=None,xlabel="Time"),
    title="NeuralLearning",
    annotations="Simulated with {}".format(sim.name())
).save("XORLearningPlotColor")

plt.show()
